# %% [markdown]
# <a href="https://www.kaggle.com/code/cnydox/aerial-detection?scriptVersionId=153940427" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# !pip install -q ultralytics comet_ml
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.

# %%
# !nvidia-smi
# Out:
# Wed Dec  6 13:16:17 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import ultralytics
from ultralytics import YOLO, settings
from IPython.display import Image, clear_output
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5173.5/8062.4 GB disk)

# %%
import comet_ml
comet_ml.init(project_name="Kaggle")
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key:  ·························
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
experiment = comet_ml.Experiment()
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Couldn't find a Git repository in '/kaggle/working' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/cnydo/kaggle/ef55644cf7ae4dfcbaa98137992cf456

# %%
experiment.display(tab="charts")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://www.comet.com/cnydo/kaggle/ef55644cf7ae4dfcbaa98137992cf456?experiment-tab=chart"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt') 
model.train(epochs=40, batch=30,
            data='/kaggle/input/aerial-object-detection/data.yaml', 
            imgsz=1088, device=0, plots=True, optimizer='Adam', lr0=0.001)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 165MB/s]
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# ...

# %%
results = model.val(data='/kaggle/input/aerial-object-detection/data.yaml',
                    save_json=True, device=0, split='val')
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# val: Scanning /kaggle/input/aerial-object-detection/val/labels... 260 images, 1920 backgrounds, 0 corrupt: 100%|██████████| 2180/2180 [00:01<00:00, 1831.72it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/aerial-object-detection/val is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 73/73 [00:31<00:00,  2.28it/s]
#                    all       2180        894      0.859      0.705       0.79      0.496
#                  Zebra       2180        434      0.801      0.725      0.783       0.45
#                Giraffe       2180        167      0.918      0.719      0.805      0.533
#               Elephant       2180        293      0.857      0.672      0.783      0.506
# Speed: 1.2ms preprocess, 5.8ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %%
experiment.end()

# %%
predicts = model('/kaggle/input/aerial-object-detection/test/images', imgsz=4000, device=device, save=True)
# Out:
# image 1/112 /kaggle/input/aerial-object-detection/test/images/DPP_00382.JPG: 2688x4000 7 Elephants, 46.3ms
# image 2/112 /kaggle/input/aerial-object-detection/test/images/DPP_00391.JPG: 2688x4000 3 Elephants, 46.2ms
# image 3/112 /kaggle/input/aerial-object-detection/test/images/DPP_00392.JPG: 2688x4000 1 Giraffe, 2 Elephants, 46.2ms
# image 4/112 /kaggle/input/aerial-object-detection/test/images/DPP_00422.JPG: 2688x4000 6 Zebras, 45.7ms
# image 5/112 /kaggle/input/aerial-object-detection/test/images/DPP_00427.JPG: 2688x4000 8 Elephants, 45.7ms
# image 6/112 /kaggle/input/aerial-object-detection/test/images/DPP_00428.JPG: 2688x4000 3 Elephants, 45.8ms
# image 7/112 /kaggle/input/aerial-object-detection/test/images/DPP_00439.JPG: 2688x4000 22 Zebras, 45.7ms
# image 8/112 /kaggle/input/aerial-object-detection/test/images/DPP_00451.JPG: 2688x4000 7 Elephants, 45.7ms
# image 9/112 /kaggle/input/aerial-object-detection/test/images/DPP_00469.JPG: 2688x4000 21 Elephants, 45.8ms
# ...

# %%
import random
from pathlib import Path
imglist = list(Path('runs/detect/train7/').glob('*.JPG'))
Image(random.choice(imglist))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 from pathlib import Path
#       3 imglist = list(Path('runs/detect/train7/').glob('*.JPG'))
# ----> 4 Image(random.choice(imglist))
#
# NameError: name 'Image' is not defined
