# %% [markdown]
# <a href="https://www.kaggle.com/code/cnydox/aerial-detection?scriptVersionId=149221614" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# %pip install ultralytics comet_ml
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5016.7/8062.4 GB disk)

# %%
# !nvidia-smi
# Out:
# Tue Oct 31 01:24:02 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    11W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
import comet_ml
comet_ml.init(project_name='animale_detection_yolov8') # UA9ka370pmUbYM418bY8YJdYY
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key:  ·························
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/kaggle/input/aerial-object-detection/data.yaml epochs=100 imgsz=640 batch=42 device=0,1 plots=True
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15110MiB)
#                                                        CUDA:1 (Tesla T4, 15110MiB)
# ...

# %%
# !yolo task=detect mode=val \
model=/kaggle/working/runs/detect/train/weights/best.pt \
data=/kaggle/input/aerial-object-detection/data.yaml
